# %%
import cfgrib
import matplotlib.pyplot as plt


ds = cfgrib.open_dataset('../data/20190204T070000Z_TT.grb')
print(ds)
# Out:
# Ignoring index file '/Users/andrejm/test-analytic/data/20190204T070000Z_TT.grb.887f8.idx' incompatible with GRIB file
# <xarray.Dataset>
# Dimensions:     (latitude: 1876, longitude: 2276)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     int64 ...
#   * latitude    (latitude) float64 34.0 34.02 34.04 34.06 ... 71.46 71.48 71.5
#   * longitude   (longitude) float64 -13.0 -12.98 -12.96 ... 32.46 32.48 32.5
#     valid_time  datetime64[ns] ...
# Data variables:
#     t           (latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             consensus
#     GRIB_centreDescription:  Consensus
#     GRIB_subCentre:          65535
#     Conventions:             CF-1.7
#     institution:             Consensus
#     history:                 2019-03-19T14:55:05 GRIB to CDM+CF via cfgrib-0....

# %%
d = ds.t.isel()
print(d)
# Out:
# <xarray.DataArray 't' (latitude: 1876, longitude: 2276)>
# [4269776 values with dtype=float32]
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     int64 ...
#   * latitude    (latitude) float64 34.0 34.02 34.04 34.06 ... 71.46 71.48 71.5
#   * longitude   (longitude) float64 -13.0 -12.98 -12.96 ... 32.46 32.48 32.5
#     valid_time  datetime64[ns] ...
# Attributes:
#     GRIB_paramId:                             130
#     GRIB_shortName:                           t
#     GRIB_units:                               K
#     GRIB_name:                                Temperature
#     GRIB_cfName:                              air_temperature
#     GRIB_cfVarName:                           t
#     GRIB_dataType:                            fc
#     GRIB_missingValue:                        9999
#     GRIB_numberOfPoints:                      4269776
#     GRIB_typeOfLevel:                         surface
# ...

# %%
d.plot()
plt.show()
